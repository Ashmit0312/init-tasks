# %% [markdown]
# # Pandas Practice Exercises
#
# This notebook contains 40+ exercises to practice your Pandas skills. The exercises start from the basics and gradually increase in difficulty.
#
# ## Datasets Used
# We will use a few common datasets available online. You can load them directly using the URLs provided in the exercises.
# 1. **Chipotle**: `https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv`
# 2. **Drinks**: `https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv`
# 3. **Titanic**: `https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv`
#
# ---
#
# ## Section 1: Getting Started & Basic Data Structures

# %%
# 1. Import pandas as pd and numpy as np
import pandas as pd
import numpy as np

# %%
# 2. Print the version of pandas that has been imported.
pd.__version__
# Out:
# '2.2.3'

# %%
# 3. Create a pandas Series from the following list:
data = [10, 20, 30, 40, 50]
# Your code here
pd.Series(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# 4. Create a DataFrame from the following dictionary:
data_dict = {
    'name': ['Alice', 'Bob', 'Charlie', 'David'],
    'age': [25, 30, 35, 40],
    'city': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}
# Your code here
df=pd.DataFrame(data_dict)

# %%
# 5. Set the 'name' column as the index of the DataFrame created in Q4.
#df.set_index('name',inplace=True)
df
# Out:
#       name  age         city
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %% [markdown]
# ---
# ## Section 2: Loading Data & Basic Exploration
# For this section, we will use the **Chipotle** dataset.
# URL: `https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv`
# *Note: This file is tab-separated.*

# %%
# 6. Load the dataset into a variable called `chipo`.
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
# Your code here
df1 = pd.read_csv(url,sep ="\t")

# %%
# 7. Show the first 10 entries of the dataframe.
df1.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
# 8. What is the number of observations (rows) and columns in the dataset?
df1.shape
# Out:
# (4622, 5)

# %%
# 9. Print the name of all the columns.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
# 10. How is the dataset indexed?
#using order_id

# %% [markdown]
# ---
# ## Section 3: Data Cleaning & Manipulation
# Continue using the `chipo` dataframe.

# %%
# 11. Check the data type of each column.
df1.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
# 12. The 'item_price' column is currently an object (string) because of the '$' sign.
# Clean this column: remove the '$' and convert it to a float.
df1['item_price']=df1['item_price'].str.replace("$","")
df1['item_price']=df1['item_price'].astype(float)
df1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
#
# [4622 rows x 5 columns]

# %%
# 13. Are there any missing values in the dataset? Check for nulls.
df1.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
# 14. Drop any duplicate rows, if they exist.
df1 = df1.drop_duplicates()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4563 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4563 non-null   int64
#  1   quantity            4563 non-null   int64
#  2   item_name           4563 non-null   object
#  3   choice_description  3335 non-null   object
#  4   item_price          4563 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 213.9+ KB

# %%
# 15. Create a new column 'revenue' which is the product of 'quantity' and 'item_price'.
df1['revenue'] = df1['quantity']*df1['item_price']
# Out:
# C:\Users\ashmi\AppData\Local\Temp\ipykernel_40880\2214249158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['revenue'] = df1['quantity']*df1['item_price']

# %% [markdown]
# ---
# ## Section 4: Filtering & Sorting

# %%
# 16. Sort the dataframe by 'item_price' in descending order.
df1.sort_values(by='item_price',ascending=False)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 3602      1443         4               Chicken Burrito
# 1254       511         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 2584      1025         1                   Canned Soda
# 107         47         1                   Canned Soda
# 87          38         1                 Bottled Water
# 3499      1405         1                 Bottled Water
# 2545      1009         1                 Bottled Water
#
#                                      choice_description  item_price  revenue
# 3598                                                NaN       44.25   663.75
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25   105.75
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       35.00   140.00
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00   140.00
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       33.75   101.25
# ...                                                 ...         ...      ...
# 2584                                     [Mountain Dew]        1.09     1.09
# 107                                        [Dr. Pepper]        1.09     1.09
# 87                                                  NaN        1.09     1.09
# 3499                                                NaN        1.09     1.09
# 2545                                                NaN        1.09     1.09
#
# [4563 rows x 6 columns]

# %%
# 17. How many items cost more than $10.00?
(df1['item_price']> 10).sum()
# Out:
# np.int64(1123)

# %%
# 18. What is the price of each item? 
# (Hint: print a dataframe with only two columns: item_name and item_price, drop duplicates)
df1[['item_name','item_price']]
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4563 rows x 2 columns]

# %%
# 19. Select only the items where the name is 'Chicken Bowl'.
df1[df1["item_name"] == "Chicken Bowl"]
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price  revenue
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98    33.96
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98    10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25    11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75     8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49     8.49
# ...                                                 ...         ...      ...
# 4590  [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25    11.25
# 4591  [Tomatillo Red Chili Salsa, [Rice, Black Beans...        8.75     8.75
# 4595  [Tomatillo Green Chili Salsa, [Rice, Black Bea...        8.75     8.75
# 4599      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]        8.75     8.75
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75     8.75
#
# [717 rows x 6 columns]

# %%
# 20. Select items where the name is 'Chicken Bowl' AND the quantity is greater than 1.
# 19. Select only the items where the name is 'Chicken Bowl'.
df1[(df1["item_name"] == "Chicken Bowl")&(df1['quantity']>1)]
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 154         70         2  Chicken Bowl
# 282        124         2  Chicken Bowl
# 409        178         3  Chicken Bowl
# 415        181         2  Chicken Bowl
# 654        271         2  Chicken Bowl
# 976        401         2  Chicken Bowl
# 1017       418         2  Chicken Bowl
# 1106       457         2  Chicken Bowl
# 1429       578         2  Chicken Bowl
# 1514       616         3  Chicken Bowl
# 1588       643         2  Chicken Bowl
# 1832       741         2  Chicken Bowl
# 2075       837         2  Chicken Bowl
# 2106       848         2  Chicken Bowl
# 2339       932         2  Chicken Bowl
# 2510       997         2  Chicken Bowl
# 2525      1004         2  Chicken Bowl
# 2580      1023         2  Chicken Bowl
# 2771      1100         2  Chicken Bowl
# 2942      1170         2  Chicken Bowl
# 3080      1227         2  Chicken Bowl
# 3133      1249         2  Chicken Bowl
# 3151      1257         2  Chicken Bowl
# 3423      1374         2  Chicken Bowl
# 3508      1410         2  Chicken Bowl
# 3612      1447         2  Chicken Bowl
# 3618      1449         2  Chicken Bowl
# 3663      1465         2  Chicken Bowl
# 3843      1540         2  Chicken Bowl
# 3976      1593         2  Chicken Bowl
# 4423      1764         2  Chicken Bowl
# 4435      1767         2  Chicken Bowl
#
#                                      choice_description  item_price  revenue
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98    33.96
# 154   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       17.50    35.00
# 282   [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       17.50    35.00
# 409   [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...       32.94    98.82
# 415                         [Tomatillo Red Chili Salsa]       17.50    35.00
# 654   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       17.50    35.00
# 976   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       17.50    35.00
# 1017  [Fresh Tomato Salsa, [Rice, Cheese, Black Beans]]       17.50    35.00
# 1106  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       17.50    35.00
# 1429  [Fresh Tomato Salsa, [Rice, Sour Cream, Guacam...       22.50    45.00
# 1514  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       26.25    78.75
# 1588  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       17.50    35.00
# 1832  [Tomatillo-Red Chili Salsa (Hot), [Sour Cream,...       21.96    43.92
# 2075  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...       21.96    43.92
# 2106  [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...       17.50    35.00
# 2339  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...       16.98    33.96
# 2510  [Roasted Chili Corn Salsa, [Rice, Black Beans,...       22.50    45.00
# 2525  [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...       21.96    43.92
# 2580  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...       16.98    33.96
# 2771  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...       16.98    33.96
# 2942  [Tomatillo-Green Chili Salsa (Medium), [Black ...       21.96    43.92
# 3080  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...       16.98    33.96
# 3133  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...       16.98    33.96
# 3151  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...       21.96    43.92
# 3423  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...       17.50    35.00
# 3508  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...       21.96    43.92
# 3612  [Tomatillo-Red Chili Salsa (Hot), [Cheese, Sou...       16.98    33.96
# 3618  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...       16.98    33.96
# 3663  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...       16.98    33.96
# 3843  [Tomatillo-Red Chili Salsa (Hot), [Rice, Pinto...       21.96    43.92
# 3976  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...       16.98    33.96
# 4423  [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...       22.50    45.00
# 4435  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       17.50    35.00

# %% [markdown]
# ---
# ## Section 5: Aggregation & Grouping
# For this section, we will use the **Drinks** dataset.
# URL: `https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv`

# %%
# 21. Load the drinks dataset into a variable called `drinks`.
url_drinks = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
# Your code here
df2 = pd.read_csv(url_drinks)
df2
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# ..                            ...       ...
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %%
# 22. Which continent drinks more beer on average?
df2.groupby('continent')['beer_servings'].mean().sort_values(ascending=False)
# Out:
# continent
# EU    193.777778
# SA    175.083333
# OC     89.687500
# AF     61.471698
# AS     37.045455
# Name: beer_servings, dtype: float64

# %%
# 23. For each continent, print the statistics for wine consumption.
df2.groupby('continent')['wine_servings'].mean().sort_values(ascending=False)
# Out:
# continent
# EU    142.222222
# SA     62.416667
# OC     35.625000
# AF     16.264151
# AS      9.068182
# Name: wine_servings, dtype: float64

# %%
# 24. Print the mean alcohol consumption per continent for every column.
df2.groupby('continent')['total_litres_of_pure_alcohol'].mean().sort_values(ascending=False)
# Out:
# continent
# EU    8.617778
# SA    6.308333
# OC    3.381250
# AF    3.007547
# AS    2.170455
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
# 25. Print the median alcohol consumption per continent for every column.
df2.groupby('continent')['beer_servings'].median().sort_values(ascending=False)
# Out:
# continent
# EU    219.0
# SA    162.5
# OC     52.5
# AF     32.0
# AS     17.5
# Name: beer_servings, dtype: float64

# %% [markdown]
# ---
# ## Section 6: Apply & Advanced Selection
# Back to the `chipo` dataset

# %%
# 26. Create a function that returns "High" if a price is > 10 and "Low" otherwise.
# Apply this function to the 'item_price' column of `chipo` and create a new column 'price_level'.
def price_level(price):
    if price > 10:
        return "High"
    else:
        return "Low"

df1['price_level'] = df1['item_price'].apply(price_level)
# Out:
# C:\Users\ashmi\AppData\Local\Temp\ipykernel_40880\3306608858.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['price_level'] = df1['item_price'].apply(price_level)

# %%
# 27. Use the `apply` method to capitalize all strings in the 'item_name' column.
def uppercase(str):
    return str.upper()
df1['item_name']=df1['item_name'].apply(uppercase)
# Out:
# C:\Users\ashmi\AppData\Local\Temp\ipykernel_40880\1662114935.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['item_name']=df1['item_name'].apply(uppercase)

# %%
# 28. Select only the rows from index 10 to 20 (inclusive) and columns 1 to 3.
df1.iloc[10:21,:4]
# Out:
#     order_id  quantity                              item_name  \
# 10         5         1                    CHIPS AND GUACAMOLE
# 11         6         1                   CHICKEN CRISPY TACOS
# 12         6         1                     CHICKEN SOFT TACOS
# 13         7         1                           CHICKEN BOWL
# 14         7         1                    CHIPS AND GUACAMOLE
# 15         8         1  CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 16         8         1                        CHICKEN BURRITO
# 17         9         1                        CHICKEN BURRITO
# 18         9         2                            CANNED SODA
# 19        10         1                           CHICKEN BOWL
# 20        10         1                    CHIPS AND GUACAMOLE
#
#                                    choice_description
# 10                                                NaN
# 11  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 12  [Roasted Chili Corn Salsa, [Rice, Black Beans,...
# 13  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 14                                                NaN
# 15                                                NaN
# 16  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...
# 17  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# 18                                           [Sprite]
# 19  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 20                                                NaN

# %% [markdown]
# ---
# ## Section 7: Merging & Joining

# %%
# 29. Create two dataframes:
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Score': [85, 90, 95]})

# Merge them on 'ID' using an inner join.
merged_dfi = pd.merge(df1, df2, on='ID', how='inner')

# %%
# 30. Merge them on 'ID' using an outer join.
merged_dfo = pd.merge(df1, df2, on='ID', how='outer')

# %%
# 31. Merge them on 'ID' using a left join (keep all from df1).
merged_dfl = pd.merge(df1, df2, on='ID', how='left')

# %% [markdown]
# ---
# ## Section 8: Time Series
# For this section, let's generate some time series data.

# %%
# 32. Create a date range from '2023-01-01' to '2023-01-10'.
date_range = pd.date_range(start='2023-01-01', end='2023-01-10')
print(date_range)
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
# 33. Create a DataFrame with this date range as the index and a column 'Sales' with random values.
dft = pd.DataFrame({
    'Sales': np.random.randint(1, 100, size=len(date_range))
}, index=date_range)

# %%
# 34. Resample the data to calculate the 3-day sum of sales.
three_day_sum = dft.resample('3D').sum()
print(three_day_sum)
# Out:
#             Sales
# 2023-01-01    130
# 2023-01-04    164
# 2023-01-07    264
# 2023-01-10     41

# %%
# 35. Shift the 'Sales' column by 1 day (create a lag column).
dft['Sales'] = dft['Sales'].shift(1)
print(dft)
# Out:
#             Sales
# 2023-01-01    NaN
# 2023-01-02   41.0
# 2023-01-03   87.0
# 2023-01-04    2.0
# 2023-01-05   35.0
# 2023-01-06   68.0
# 2023-01-07   61.0
# 2023-01-08   96.0
# 2023-01-09   95.0
# 2023-01-10   73.0

# %% [markdown]
# ---
# ## Section 9: Titanic Dataset - Mixed Practice
# URL: `https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv`

# %%
# 36. Load the Titanic dataset.
url_titanic = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
# Your code here
ti = pd.read_csv(url_titanic)
ti
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# 37. How many passengers survived? (Survived=1)
ti['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# 38. What is the average age of passengers?
print(ti['Age'].mean())
# Out:
# 29.69911764705882

# %%
# 39. Group by 'Pclass' and calculate the survival rate (mean of 'Survived').
ti.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
# 40. Fill missing values in the 'Age' column with the median age.
from sklearn.impute import SimpleImputer
import numpy as np
imputer = SimpleImputer(strategy='median')
ti['Age'] = imputer.fit_transform(ti[['Age']])
ti
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# 41. Create a pivot table showing the average age by 'Sex' and 'Pclass'.
pivot = pd.pivot_table(
    ti,
    values='Age',
    index='Sex',
    columns='Pclass',
    aggfunc='mean'
)

# %% [markdown]
# ---
# ## Section 10: Visualization (Optional)
# Requires matplotlib/seaborn

# %%
# 42. Plot a histogram of the 'Age' column from the Titanic dataset.
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(ti['Age'].dropna())
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %%
# 43. Plot a bar chart of the average fare by Pclass.
avg_fare = ti.groupby('Pclass')['Fare'].mean()

plt.figure(figsize=(8,5))
plt.bar(avg_fare.index, avg_fare.values)
plt.xlabel('Pclass')
plt.ylabel('Average Fare')
plt.title('Average Fare by Passenger Class')
plt.show()

# %% [markdown]
# ---
# ## Great Job!
# You've covered the basics of Pandas including creating objects, reading data, cleaning, filtering, grouping, merging, and time series.
